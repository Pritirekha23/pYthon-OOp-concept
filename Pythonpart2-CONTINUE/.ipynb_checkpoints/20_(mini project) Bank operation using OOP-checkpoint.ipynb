# %%
#dt-08/01/2023

class Bank:
    bankname="Canara Bank"
    branch='Dhamanagra,Bhadrak,India'
    
    # create account
    def __init__(self,username,pan,address):
        self.username=username
        self.pan=pan
        self.address=address
        self.balance=0.0
        print(f'Hello {self.username} congratulations! your account created successfully')
    
    
    #deposit
    def deposit(self,amount):
        self.balance=self.balance+amount
        print(f'{amount} deposited successfully')
        
    #withdraw
    def withdraw(self,amount):
        if amount<self.balance:
            self.balance=self.balance-amount
            print(f'{amount} withdraw successfully')
        else:
            print('Insufficient balance')
        
     #ministatement
    def ministatement(self):
        print(f'your account balance is {self.balance}')
        
        
        
        
print(f'Welcome to {Bank.bankname},{Bank.branch}')
#collect user data for account creation
username=input('Enter your name ::')           
pan=input('Enter your pan number ::') 
address=input('Enter your address ::')


#object creation based on user provided data
b=Bank(username,pan,address)

while True:
    print('please Select any option ::')
    print('1.Deposit\n 2.Withdra\n 3.Ministatement\n 4.Stop\n')
    option=int(input(' '))
    
    if option==1:
        amount=float(input('Enter deposited amount::'))
        b.deposit(amount)
        
    elif option==2:
        amount=float(input('Enter withdraw amount::'))
        b.withdraw(amount)
        
    elif option==3:
        b.ministatement()
        
    elif option==4:
        print('Thanks for using Canara bank')
        break
        
    else:
        print('Chhose a valid option')
# Out:
# Welcome to Canara Bank,Dhamanagra,Bhadrak,India
# Enter your name ::Ramakanta panda
# Enter your pan number ::54thbH
# Enter your address ::BDk
# Hello Ramakanta panda congratulations! your account created successfully
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  1
# Enter deposited amount::600
# 600.0 deposited successfully
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  3
# your account balance is 600.0
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  7
# Chhose a valid option
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  3
# your account balance is 600.0
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  2
# Enter withdraw amount::1000
# Insufficient balance
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  3
# your account balance is 600.0
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  2
# Enter withdraw amount::500
# 500.0 withdraw successfully
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  3
# your account balance is 100.0
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  1
# Enter deposited amount::1000
# 1000.0 deposited successfully
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  3
# your account balance is 1100.0
# please Select any option ::
# 1.Deposit
#  2.Withdra
#  3.Ministatement
#  4.Stop
#
#  4
# Thanks for using Canara bank
